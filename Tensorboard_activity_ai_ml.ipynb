# %%
import numpy as np
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical as to_categorical
from tensorflow.keras.layers import Dense, Input, Dropout
from keras import regularizers
import tensorflow as tf
from os.path import join
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.datasets import mnist
from keras.src.layers.reshaping.flatten import Flatten
from tensorflow.keras.layers import Flatten

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
y_train=to_categorical(y_train, num_classes=10)
y_test=to_categorical(y_test, num_classes=10)

# %%
model= Sequential()
model.add(Input(shape=(28,28,1)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.1563 - loss: 2.9329 - val_accuracy: 0.2081 - val_loss: 2.0143
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2099 - loss: 2.0153 - val_accuracy: 0.2106 - val_loss: 1.9949
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2129 - loss: 1.9911 - val_accuracy: 0.2206 - val_loss: 1.9784
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2429 - loss: 1.9234 - val_accuracy: 0.3207 - val_loss: 1.6687
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.3580 - loss: 1.6169 - val_accuracy: 0.3874 - val_loss: 1.5053
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.4951 - loss: 1.3300 - val_accuracy: 0.7744 - val_loss: 0.7317
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7863 - loss: 0.6370 - val_accuracy: 0.8251 - val_loss: 0.5506
# Epoch 8/10
# ...

# %%
log_dir=join("logs", "fit", "Model1")
tfcb=tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history=model.fit(x_train, y_train, epochs=10, batch_size=32, callbacks=[tfcb], validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9440 - loss: 0.2440 - val_accuracy: 0.9323 - val_loss: 0.3792
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9466 - loss: 0.2232 - val_accuracy: 0.9377 - val_loss: 0.3948
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9521 - loss: 0.2026 - val_accuracy: 0.9402 - val_loss: 0.3426
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9551 - loss: 0.1899 - val_accuracy: 0.9431 - val_loss: 0.3614
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9582 - loss: 0.1766 - val_accuracy: 0.9441 - val_loss: 0.3837
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9589 - loss: 0.1739 - val_accuracy: 0.9433 - val_loss: 0.4209
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9614 - loss: 0.1567 - val_accuracy: 0.9409 - val_loss: 0.3991
# Epoch 8/10
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit
# %reload_ext tensorboard

# %%
model1= Sequential()
model1.add(Input(shape=(28,28,1)))
model1.add(Flatten())
model1.add(Dense(64, activation='relu'), regularizers.l2(0.01))
model1.add(Dense(32, activation='relu'), regularizers.l2(0.01))
model1.add(Dense(10, activation='softmax'), regularizers.l1_l2(l1=1e-5, l2=1e-4))

# %%
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history=model1.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.4738 - loss: 3.8298 - val_accuracy: 0.8144 - val_loss: 0.6043
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8542 - loss: 0.4875 - val_accuracy: 0.9211 - val_loss: 0.2759
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9313 - loss: 0.2489 - val_accuracy: 0.9377 - val_loss: 0.2345
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9475 - loss: 0.1885 - val_accuracy: 0.9424 - val_loss: 0.2087
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9550 - loss: 0.1591 - val_accuracy: 0.9534 - val_loss: 0.1786
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9621 - loss: 0.1384 - val_accuracy: 0.9548 - val_loss: 0.1799
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9631 - loss: 0.1286 - val_accuracy: 0.9565 - val_loss: 0.1600
# Epoch 8/10
# ...

# %%
log_dir=join("logs", "fit", "Model1")
tfcba=tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True)

# %%
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history=model1.fit(x_train, y_train, epochs=10, batch_size=32, callbacks=[tfcba], validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9730 - loss: 0.1024 - val_accuracy: 0.9638 - val_loss: 0.1524
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9763 - loss: 0.0871 - val_accuracy: 0.9647 - val_loss: 0.1443
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9770 - loss: 0.0857 - val_accuracy: 0.9563 - val_loss: 0.1854
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9781 - loss: 0.0796 - val_accuracy: 0.9512 - val_loss: 0.2318
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9768 - loss: 0.0825 - val_accuracy: 0.9674 - val_loss: 0.1726
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9801 - loss: 0.0726 - val_accuracy: 0.9696 - val_loss: 0.1513
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9817 - loss: 0.0661 - val_accuracy: 0.9688 - val_loss: 0.1648
# Epoch 8/10
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit
# %reload_ext tensorboard

# %%
model2= Sequential()
model2.add(Input(shape=(28,28,1)))
model2.add(Flatten())
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(32, activation='relu'))
model2.add(Dense(10, activation='softmax'))

# %%
log_dir=join("logs", "fit", "Model1")
tfcbg=tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True)

# %%
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history=model1.fit(x_train, y_train, epochs=10, batch_size=32, callbacks=[tfcbg], validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9803 - loss: 0.0696 - val_accuracy: 0.9653 - val_loss: 0.1873
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9824 - loss: 0.0637 - val_accuracy: 0.9675 - val_loss: 0.1678
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9852 - loss: 0.0555 - val_accuracy: 0.9654 - val_loss: 0.1834
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9836 - loss: 0.0602 - val_accuracy: 0.9649 - val_loss: 0.1832
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9839 - loss: 0.0622 - val_accuracy: 0.9692 - val_loss: 0.1713
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9860 - loss: 0.0538 - val_accuracy: 0.9630 - val_loss: 0.2036
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9858 - loss: 0.0510 - val_accuracy: 0.9675 - val_loss: 0.1951
# Epoch 8/10
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit
# %reload_ext tensorboard
